# %%
import numpy as np
import numpy.random as npr
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/homes.csv')
print(df.describe())
# Out:
#              Sell      "List"   "Living"    "Rooms"     "Beds"    "Baths"  \
# count   50.000000   50.000000  50.000000  50.000000  50.000000  50.000000
# mean   170.360000  178.340000  21.120000   8.060000   3.820000   1.860000
# std     72.755885   79.382723   8.351072   1.284285   0.690755   0.756199
# min     87.000000   90.000000  10.000000   5.000000   3.000000   1.000000
# 25%    135.000000  140.000000  17.000000   7.000000   3.000000   1.000000
# 50%    152.000000  160.000000  20.000000   8.000000   4.000000   2.000000
# 75%    182.250000  190.000000  22.750000   9.000000   4.000000   2.000000
# max    567.000000  625.000000  64.000000  12.000000   6.000000   4.000000
#
#             "Age"    "Acres"       "Taxes"
# count   50.000000  50.000000     50.000000
# mean    30.220000   1.020600   3706.100000
# std     30.962314   1.191496   1579.915268
# min      2.000000   0.220000   1445.000000
# 25%     12.250000   0.382500   3107.000000
# ...

# %%
# EDA Technique 1: Summary Statistics and Data Information
print("\n--- EDA Technique 1: Summary Statistics and Data Information ---")
print("Why: To get an overview of the data, its structure, and basic statistical properties.")
print("What: Using df.info() to check data types and null values, and df.describe() for numerical summaries.")

print("\nData Info:")
print(df.info())

print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# --- EDA Technique 1: Summary Statistics and Data Information ---
# Why: To get an overview of the data, its structure, and basic statistical properties.
# What: Using df.info() to check data types and null values, and df.describe() for numerical summaries.
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sell       50 non-null     int64
#  1    "List"    50 non-null     int64
#  2    "Living"  50 non-null     int64
#  3    "Rooms"   50 non-null     int64
#  4    "Beds"    50 non-null     int64
#  5    "Baths"   50 non-null     int64
#  6    "Age"     50 non-null     int64
#  7    "Acres"   50 non-null     float64
#  8    "Taxes"   50 non-null     int64
# dtypes: float64(1), int64(8)
# memory usage: 3.6 KB
# None
#
# Descriptive Statistics:
#              Sell      "List"   "Living"    "Rooms"     "Beds"    "Baths"  \
# ...

# %%
# EDA Technique 2: Distribution of Numerical Columns (Histograms)
print("\n--- EDA Technique 2: Distribution of Numerical Columns (Histograms) ---")
print("Why: To visualize the distribution of numerical data and identify potential outliers or skewness.")
print("What: Creating histograms for each numerical column using matplotlib.")

numerical_cols = df.select_dtypes(include=['number']).columns
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# --- EDA Technique 2: Distribution of Numerical Columns (Histograms) ---
# Why: To visualize the distribution of numerical data and identify potential outliers or skewness.
# What: Creating histograms for each numerical column using matplotlib.

# %%
# EDA Technique 3: Correlation Heatmap
print("\n--- EDA Technique 3: Correlation Heatmap ---")
print("Why: To understand the relationships between numerical variables and identify potential correlations.")
print("What: Creating a correlation heatmap using seaborn.")

correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# --- EDA Technique 3: Correlation Heatmap ---
# Why: To understand the relationships between numerical variables and identify potential correlations.
# What: Creating a correlation heatmap using seaborn.

# %%
X = df['Taxes']  # Independent variable
y = df['Sell']   # Dependent variable

# Add a constant term to the independent variable (for the intercept)
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Display the model summary
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\app\AppData\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Taxes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 X = df['Taxes']  # Independent variable
# ...
