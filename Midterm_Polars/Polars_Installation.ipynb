# %% [markdown]
# To install the Polars library in Python, you can use the Python package installer pip. Here are the steps to install Polars:
#
# Open your command line interface (CLI), such as Terminal on macOS, Command Prompt or PowerShell on Windows, or your preferred terminal emulator on Linux.
#
# Ensure your pip is up to date. It's generally a good practice to make sure you have the latest version of pip before installing new packages. You can update pip using the following command:
#
# bash
# Copy

# %% [markdown]
# Install Polars. Run the following command to install the Polars library. Adding the Polars[all] option allows you to utilize a wide range of Polars features.

# %%
pip install polars "polars[all]"
# Out:
# Requirement already satisfied: polars in c:\app\appdata\lib\site-packages (1.26.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\app\appdata\lib\site-packages (from polars) (1.26.4)
# Requirement already satisfied: pandas in c:\app\appdata\lib\site-packages (from polars) (2.2.2)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\app\appdata\lib\site-packages (from polars) (16.1.0)
# Requirement already satisfied: pydantic in c:\app\appdata\lib\site-packages (from polars) (2.8.2)
# Requirement already satisfied: fsspec in c:\app\appdata\lib\site-packages (from polars) (2024.6.1)
# Collecting deltalake>=0.19.0 (from polars)
#   Downloading deltalake-0.25.5-cp39-abi3-win_amd64.whl.metadata (5.6 kB)
# Collecting pyiceberg>=0.7.1 (from polars)
#   Downloading pyiceberg-0.9.0-cp312-cp312-win_amd64.whl.metadata (4.4 kB)
# Collecting gevent (from polars)
#   Downloading gevent-24.11.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: cloudpickle in c:\app\appdata\lib\site-packages (from polars) (3.0.0)
# Requirement already satisfied: matplotlib in c:\app\appdata\lib\site-packages (from polars) (3.9.2)
# Collecting altair>=5.4.0 (from polars)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting great-tables>=0.8.0 (from polars)
#   Downloading great_tables-0.17.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tzdata in c:\app\appdata\lib\site-packages (from polars) (2023.3)
# Requirement already satisfied: jinja2 in c:\app\appdata\lib\site-packages (from altair>=5.4.0->polars) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\app\appdata\lib\site-packages (from altair>=5.4.0->polars) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair>=5.4.0->polars)
#   Downloading narwhals-1.33.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: packaging in c:\app\appdata\lib\site-packages (from altair>=5.4.0->polars) (24.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\app\appdata\lib\site-packages (from altair>=5.4.0->polars) (4.11.0)
# Collecting commonmark>=0.9.1 (from great-tables>=0.8.0->polars)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting faicons>=0.2.2 (from great-tables>=0.8.0->polars)
#   Downloading faicons-0.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting htmltools>=0.4.1 (from great-tables>=0.8.0->polars)
#   Downloading htmltools-0.6.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: importlib-metadata in c:\app\appdata\lib\site-packages (from great-tables>=0.8.0->polars) (7.0.1)
# Collecting Babel>=2.13.1 (from great-tables>=0.8.0->polars)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting importlib-resources (from great-tables>=0.8.0->polars)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting cachetools<6.0.0,>=5.5.0 (from pyiceberg>=0.7.1->polars)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (8.1.7)
# Collecting mmh3<6.0.0,>=4.0.0 (from pyiceberg>=0.7.1->polars)
#   Downloading mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (13.7.1)
# Requirement already satisfied: sortedcontainers==2.4.0 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (2.4.0)
# Collecting strictyaml<2.0.0,>=1.7.0 (from pyiceberg>=0.7.1->polars)
#   Downloading strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in c:\app\appdata\lib\site-packages (from pyiceberg>=0.7.1->polars) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\app\appdata\lib\site-packages (from pydantic->polars) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\app\appdata\lib\site-packages (from pydantic->polars) (2.20.1)
# Collecting zope.event (from gevent->polars)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: zope.interface in c:\app\appdata\lib\site-packages (from gevent->polars) (5.4.0)
# Collecting greenlet>=3.1.1 (from gevent->polars)
#   Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: cffi>=1.17.1 in c:\app\appdata\lib\site-packages (from gevent->polars) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\app\appdata\lib\site-packages (from matplotlib->polars) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\app\appdata\lib\site-packages (from pandas->polars) (2024.1)
# Collecting adbc-driver-manager[dbapi] (from polars)
#   Downloading adbc_driver_manager-1.5.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting adbc-driver-sqlite[dbapi] (from polars)
#   Downloading adbc_driver_sqlite-1.5.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting connectorx>=0.3.2 (from polars)
#   Downloading connectorx-0.4.2-cp312-none-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: sqlalchemy in c:\app\appdata\lib\site-packages (from polars) (2.0.34)
# Collecting fastexcel>=0.9 (from polars)
#   Downloading fastexcel-0.13.0-cp39-abi3-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: openpyxl>=3.0.0 in c:\app\appdata\lib\site-packages (from polars) (3.1.5)
# Collecting xlsx2csv>=0.8.0 (from polars)
#   Downloading xlsx2csv-0.8.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting xlsxwriter (from polars)
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pycparser in c:\app\appdata\lib\site-packages (from cffi>=1.17.1->gevent->polars) (2.21)
# Requirement already satisfied: colorama in c:\app\appdata\lib\site-packages (from click<9.0.0,>=7.1.1->pyiceberg>=0.7.1->polars) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\app\appdata\lib\site-packages (from jsonschema>=3.0->altair>=5.4.0->polars) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\app\appdata\lib\site-packages (from jsonschema>=3.0->altair>=5.4.0->polars) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\app\appdata\lib\site-packages (from jsonschema>=3.0->altair>=5.4.0->polars) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\app\appdata\lib\site-packages (from jsonschema>=3.0->altair>=5.4.0->polars) (0.10.6)
# Requirement already satisfied: et-xmlfile in c:\app\appdata\lib\site-packages (from openpyxl>=3.0.0->polars) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\app\appdata\lib\site-packages (from python-dateutil>=2.7->matplotlib->polars) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\app\appdata\lib\site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.7.1->polars) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\app\appdata\lib\site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.7.1->polars) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\app\appdata\lib\site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.7.1->polars) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\app\appdata\lib\site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.7.1->polars) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\app\appdata\lib\site-packages (from rich<14.0.0,>=10.11.0->pyiceberg>=0.7.1->polars) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\app\appdata\lib\site-packages (from rich<14.0.0,>=10.11.0->pyiceberg>=0.7.1->polars) (2.15.1)
# Requirement already satisfied: zipp>=0.5 in c:\app\appdata\lib\site-packages (from importlib-metadata->great-tables>=0.8.0->polars) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\app\appdata\lib\site-packages (from jinja2->altair>=5.4.0->polars) (2.1.3)
# Requirement already satisfied: setuptools in c:\app\appdata\lib\site-packages (from zope.event->gevent->polars) (75.1.0)
# Requirement already satisfied: mdurl~=0.1 in c:\app\appdata\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->pyiceberg>=0.7.1->polars) (0.1.0)
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    --------------------------------------- 731.2/731.2 kB 10.0 MB/s eta 0:00:00
# Downloading deltalake-0.25.5-cp39-abi3-win_amd64.whl (38.2 MB)
#    ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.2 MB 17.5 MB/s eta 0:00:03
#    - -------------------------------------- 1.0/38.2 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.8/38.2 MB 2.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.9/38.2 MB 3.4 MB/s eta 0:00:11
#    --- ------------------------------------ 3.7/38.2 MB 3.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.0/38.2 MB 4.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/38.2 MB 3.8 MB/s eta 0:00:09
#    ------- -------------------------------- 7.1/38.2 MB 4.2 MB/s eta 0:00:08
#    -------- ------------------------------- 8.1/38.2 MB 4.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 10.2/38.2 MB 4.9 MB/s eta 0:00:06
#    ------------ --------------------------- 12.1/38.2 MB 5.3 MB/s eta 0:00:05
#    --------------- ------------------------ 14.7/38.2 MB 5.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.0/38.2 MB 6.3 MB/s eta 0:00:04
#    -------------------- ------------------- 19.7/38.2 MB 6.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.5/38.2 MB 7.2 MB/s eta 0:00:03
#    -------------------------- ------------- 25.2/38.2 MB 7.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.8/38.2 MB 7.8 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    ------------------------------ --------- 28.8/38.2 MB 7.9 MB/s eta 0:00:02
#    -------------------------------- ------- 30.9/38.2 MB 5.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.3/38.2 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 35.7/38.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.2 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.2/38.2 MB 6.2 MB/s eta 0:00:00
# Downloading great_tables-0.17.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------------------ --------- 1.0/1.4 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.8 MB/s eta 0:00:00
# Downloading pyiceberg-0.9.0-cp312-cp312-win_amd64.whl (593 kB)
#    ---------------------------------------- 0.0/593.8 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/593.8 kB ? eta -:--:--
#    --------------------------------- ---- 524.3/593.8 kB 764.3 kB/s eta 0:00:01
#    -------------------------------------- 593.8/593.8 kB 850.5 kB/s eta 0:00:00
# Downloading gevent-24.11.1-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 10.2 MB/s eta 0:00:00
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/10.2 MB 11.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.9/10.2 MB 8.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.2 MB 5.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.2 MB 5.3 MB/s eta 0:00:02
#    -------------------- ------------------- 5.2/10.2 MB 5.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.0/10.2 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.2 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.2 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.9/10.2 MB 4.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.2 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 4.1 MB/s eta 0:00:00
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Downloading connectorx-0.4.2-cp312-none-win_amd64.whl (32.4 MB)
#    ---------------------------------------- 0.0/32.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/32.4 MB 11.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 3.9/32.4 MB 11.7 MB/s eta 0:00:03
#    ------ --------------------------------- 5.0/32.4 MB 9.7 MB/s eta 0:00:03
#    ------ --------------------------------- 5.0/32.4 MB 9.7 MB/s eta 0:00:03
#    ------ --------------------------------- 5.0/32.4 MB 9.7 MB/s eta 0:00:03
#    ------ --------------------------------- 5.2/32.4 MB 4.5 MB/s eta 0:00:07
#    ------- -------------------------------- 6.3/32.4 MB 4.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 8.1/32.4 MB 4.8 MB/s eta 0:00:06
#    ------------- -------------------------- 10.7/32.4 MB 5.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 13.6/32.4 MB 6.5 MB/s eta 0:00:03
#    ------------------- -------------------- 16.0/32.4 MB 7.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 18.6/32.4 MB 7.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 18.9/32.4 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 19.1/32.4 MB 4.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 19.4/32.4 MB 4.6 MB/s eta 0:00:03
#    ------------------------- -------------- 20.7/32.4 MB 4.7 MB/s eta 0:00:03
#    --------------------------- ------------ 22.0/32.4 MB 4.8 MB/s eta 0:00:03
#    --------------------------- ------------ 22.5/32.4 MB 4.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 23.3/32.4 MB 4.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 23.6/32.4 MB 4.6 MB/s eta 0:00:02
#    ------------------------------ --------- 24.6/32.4 MB 4.5 MB/s eta 0:00:02
#    -------------------------------- ------- 26.2/32.4 MB 4.6 MB/s eta 0:00:02
#    -------------------------------- ------- 26.7/32.4 MB 4.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 28.0/32.4 MB 4.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 28.6/32.4 MB 4.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 28.8/32.4 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 30.4/32.4 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 31.5/32.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  32.0/32.4 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 32.4/32.4 MB 4.4 MB/s eta 0:00:00
# Downloading faicons-0.2.2-py3-none-any.whl (607 kB)
#    ---------------------------------------- 0.0/607.2 kB ? eta -:--:--
#    --------------------------------------- 607.2/607.2 kB 10.8 MB/s eta 0:00:00
# Downloading fastexcel-0.13.0-cp39-abi3-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ----------------------------- ---------- 0.8/1.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.4 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Downloading htmltools-0.6.0-py3-none-any.whl (84 kB)
# Downloading mmh3-5.1.0-cp312-cp312-win_amd64.whl (41 kB)
# Downloading narwhals-1.33.0-py3-none-any.whl (322 kB)
# Downloading strictyaml-1.7.3-py3-none-any.whl (123 kB)
# Downloading xlsx2csv-0.8.4-py3-none-any.whl (15 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Downloading adbc_driver_manager-1.5.0-cp312-cp312-win_amd64.whl (533 kB)
#    ---------------------------------------- 0.0/533.6 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/533.6 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/533.6 kB ? eta -:--:--
#    -------------------------------------- 533.6/533.6 kB 580.0 kB/s eta 0:00:00
# Downloading adbc_driver_sqlite-1.5.0-py3-none-win_amd64.whl (862 kB)
#    ---------------------------------------- 0.0/862.8 kB ? eta -:--:--
#    ---------------------------------------- 862.8/862.8 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: xlsx2csv, commonmark, zope.event, xlsxwriter, narwhals, mmh3, importlib-resources, htmltools, greenlet, connectorx, cachetools, Babel, adbc-driver-manager, strictyaml, gevent, fastexcel, faicons, deltalake, adbc-driver-sqlite, pyiceberg, great-tables, altair
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.1
#     Uninstalling greenlet-3.0.1:
#       Successfully uninstalled greenlet-3.0.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.3
#     Uninstalling cachetools-5.3.3:
#       Successfully uninstalled cachetools-5.3.3
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.11.0
#     Uninstalling Babel-2.11.0:
#       Successfully uninstalled Babel-2.11.0
#   Attempting uninstall: altair
#     Found existing installation: altair 5.0.1
#     Uninstalling altair-5.0.1:
#       Successfully uninstalled altair-5.0.1
# Successfully installed Babel-2.17.0 adbc-driver-manager-1.5.0 adbc-driver-sqlite-1.5.0 altair-5.5.0 cachetools-5.5.2 commonmark-0.9.1 connectorx-0.4.2 deltalake-0.25.5 faicons-0.2.2 fastexcel-0.13.0 gevent-24.11.1 great-tables-0.17.0 greenlet-3.1.1 htmltools-0.6.0 importlib-resources-6.5.2 mmh3-5.1.0 narwhals-1.33.0 pyiceberg-0.9.0 strictyaml-1.7.3 xlsx2csv-0.8.4 xlsxwriter-3.2.2 zope.event-5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This command will download and install Polars along with its dependencies. Once the installation is complete, you can import Polars in your Python scripts or Jupyter notebooks with:

# %%
import polars as pl
